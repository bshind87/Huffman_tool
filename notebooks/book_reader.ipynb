# %% [markdown]
# ## Book Reader application using Huffman coding

# %%
# !pip install graphviz

# %% [markdown]
# #### Compress the book

# %%
import os
import sys

# Determine the project root (one directory above 'notebooks')
project_root = os.path.dirname(os.getcwd())

# Path to the directory containing chunk_compressor.py
code_dir = os.path.join(project_root, "code")

# Add that directory to Python's module search path
if code_dir not in sys.path:
    sys.path.append(code_dir)

# Now you can import chunk_compressor
from chunk_compressor import chunk_book

# Use an absolute path to your input file
input_path = "/Users/bhalchandra/SEM1_NEU/huffman_tool/data/Hints on news reporting by Murray Sheehan.txt"
chunk_book(input_path)
# Out:
# Compression Done!
# Generated: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/Hints on news reporting by Murray Sheehan.txt.huff
# Generated: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/Hints on news reporting by Murray Sheehan.txt.huff.freq.json

# %% [markdown]
# #### Below launches the reader application

# %%
# !python ../code/huffman_reader.py

# %%
import os
import sys

# Determine the project root (one directory above 'notebooks')
project_root = os.path.dirname(os.getcwd())

# Path to the directory containing chunk_compressor.py
code_dir = os.path.join(project_root, "code")

# Add that directory to Python's module search path
if code_dir not in sys.path:
    sys.path.append(code_dir)

# Now you can import chunk_compressor
from chunk_compressor import chunk_book

# Use an absolute path to your input file
input_path = "/Users/bhalchandra/SEM1_NEU/huffman_tool/data/sample_book.txt"
chunk_book(input_path)
# Out:
# Compression Done!
# Generated: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/sample_book.txt.huff
# Generated: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/sample_book.txt.huff.freq.json
