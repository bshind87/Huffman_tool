# %% [markdown]
# # Huffman Tool execution steps

# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /opt/anaconda3/envs/ML/lib/python3.13/site-packages (0.21)

# %% [markdown]
# ### Char level encoding

# %%
# !python ../code/huffman_tool.py sample_char.txt compress char
# Out:
# [INFO] Building global frequency table for: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/sample_char.txt
# [INFO] Building global Huffman tree...
# [INFO] Writing code report: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/sample_char_codes.txt
# [INFO] Code report saved to: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/sample_char_codes.txt
# [INFO] Writing global metadata: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/sample_char.txt.huff.global.json
# [INFO] Starting second pass: encoding with global codes...
# [INFO] Writing chunk metadata: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/sample_char.txt.huff.chunks.json
# [INFO] Actual compression ratio (file sizes): 44.65%
#        Original size:   422448 bytes
#        Compressed size: 233832 bytes
# [INFO] Streaming hybrid compression complete.
# [INFO] Huffman tree saved as /Users/bhalchandra/SEM1_NEU/huffman_tool/output/sample_char_tree.png

# %% [markdown]
# ### Decoding Char level encoded .huff file

# %%
# !python ../code/huffman_tool.py sample_char.txt.huff decompress char
# Out:
# [INFO] Decompressing /Users/bhalchandra/SEM1_NEU/huffman_tool/output/sample_char.txt.huff
#        Mode: char, Chunks: 1
# [INFO] Decompression complete. Output: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/uncompressed_sample_char.txt.txt

# %% [markdown]
# ### Word level encoding

# %%
# !python ../code/huffman_tool.py sample_word.txt compress word
# Out:
# [INFO] Building global frequency table for: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/sample_word.txt
# [INFO] Building global Huffman tree...
# [INFO] Writing code report: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/sample_word_codes.txt
# [INFO] Code report saved to: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/sample_word_codes.txt
# [INFO] Writing global metadata: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/sample_word.txt.huff.global.json
# [INFO] Starting second pass: encoding with global codes...
# [INFO] Writing chunk metadata: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/sample_word.txt.huff.chunks.json
# [INFO] Actual compression ratio (file sizes): 77.73%
#        Original size:   422448 bytes
#        Compressed size: 94074 bytes
# [INFO] Streaming hybrid compression complete.
# [INFO] Huffman tree saved as /Users/bhalchandra/SEM1_NEU/huffman_tool/output/sample_word_tree.png

# %% [markdown]
# ### Decoding word level encoded .huff file

# %%
# !python ../code/huffman_tool.py sample_word.txt.huff decompress word
# Out:
# [INFO] Decompressing /Users/bhalchandra/SEM1_NEU/huffman_tool/output/sample_word.txt.huff
#        Mode: word, Chunks: 1
# [INFO] Decompression complete. Output: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/uncompressed_sample_word.txt.txt

# %% [markdown]
# ### Best, Average and Worst case analysis for char and word encoding

# %%
# !python ../code/test_cases.py
# Out:
# ================================================================================
# DIRECT (In-Memory) HUFFMAN TESTS — CHAR MODE
# ================================================================================
#
# --- CHAR TEST: best_case ---
# Encoded bits: 68
# Decoded OK: False
# [INFO] Huffman tree saved as /Users/bhalchandra/SEM1_NEU/huffman_tool/test/trees/tree_char_best_case.png.png
#
# --- CHAR TEST: average_case ---
# Encoded bits: 194
# Decoded OK: False
# [INFO] Huffman tree saved as /Users/bhalchandra/SEM1_NEU/huffman_tool/test/trees/tree_char_average_case.png.png
#
# --- CHAR TEST: worst_case ---
# Encoded bits: 154
# Decoded OK: False
# [INFO] Huffman tree saved as /Users/bhalchandra/SEM1_NEU/huffman_tool/test/trees/tree_char_worst_case.png.png
#
# ================================================================================
# DIRECT (In-Memory) HUFFMAN TESTS — WORD MODE
# ================================================================================
#
# --- WORD TEST: best_case ---
# Encoded bits: 28
# Decoded OK: False
# [INFO] Huffman tree saved as /Users/bhalchandra/SEM1_NEU/huffman_tool/test/trees/tree_word_best_case.png.png
#
# --- WORD TEST: average_case ---
# Encoded bits: 66
# Decoded OK: False
# [INFO] Huffman tree saved as /Users/bhalchandra/SEM1_NEU/huffman_tool/test/trees/tree_word_average_case.png.png
#
# --- WORD TEST: worst_case ---
# Encoded bits: 46
# Decoded OK: False
# [INFO] Huffman tree saved as /Users/bhalchandra/SEM1_NEU/huffman_tool/test/trees/tree_word_worst_case.png.png
#
# ================================================================================
# STREAMING HYBRID CHUNKED TESTS
# ================================================================================
#
# --- STREAM TEST: stream_char.txt (mode=char) ---
# [INFO] Building global frequency table for: /Users/bhalchandra/SEM1_NEU/huffman_tool/test/input/stream_char.txt
# [INFO] Building global Huffman tree...
# [INFO] Writing code report: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/stream_char_codes.txt
# [INFO] Code report saved to: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/stream_char_codes.txt
# [INFO] Writing global metadata: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/stream_char.txt.huff.global.json
# [INFO] Starting second pass: encoding with global codes...
# [INFO] Writing chunk metadata: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/stream_char.txt.huff.chunks.json
# [INFO] Actual compression ratio (file sizes): 46.81%
#        Original size:   47 bytes
#        Compressed size: 25 bytes
# [INFO] Streaming hybrid compression complete.
# [INFO] Huffman tree saved as /Users/bhalchandra/SEM1_NEU/huffman_tool/output/stream_char_tree.png
# [INFO] huff file: output/stream_char.txt.huff
# [INFO] global meta: output/stream_char.txt.huff.global.json
# [INFO] chunk meta: output/stream_char.txt.huff.chunks.json
# [ERROR] Missing .huff output!
#
# --- STREAM TEST: stream_word.txt (mode=word) ---
# [INFO] Building global frequency table for: /Users/bhalchandra/SEM1_NEU/huffman_tool/test/input/stream_word.txt
# [INFO] Building global Huffman tree...
# [INFO] Writing code report: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/stream_word_codes.txt
# [INFO] Code report saved to: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/stream_word_codes.txt
# [INFO] Writing global metadata: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/stream_word.txt.huff.global.json
# [INFO] Starting second pass: encoding with global codes...
# [INFO] Writing chunk metadata: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/stream_word.txt.huff.chunks.json
# [INFO] Actual compression ratio (file sizes): 87.84%
#        Original size:   74 bytes
#        Compressed size: 9 bytes
# [INFO] Streaming hybrid compression complete.
# [INFO] Huffman tree saved as /Users/bhalchandra/SEM1_NEU/huffman_tool/output/stream_word_tree.png
# [INFO] huff file: output/stream_word.txt.huff
# [INFO] global meta: output/stream_word.txt.huff.global.json
# [INFO] chunk meta: output/stream_word.txt.huff.chunks.json
# [ERROR] Missing .huff output!
#
# All tests completed.

# %% [markdown]
# ### Large book compression and decompression

# %%
# !python ../code/huffman_tool.py large_book.txt compress word
# Out:
# [INFO] Building global frequency table for: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/large_book.txt
# [INFO] Building global Huffman tree...
# [INFO] Writing code report: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/large_book_codes.txt
# [INFO] Code report saved to: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/large_book_codes.txt
# [INFO] Writing global metadata: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/large_book.txt.huff.global.json
# [INFO] Starting second pass: encoding with global codes...
# [INFO] Writing chunk metadata: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/large_book.txt.huff.chunks.json
# [INFO] Actual compression ratio (file sizes): 65.19%
#        Original size:   5441600 bytes
#        Compressed size: 1893952 bytes
# [INFO] Streaming hybrid compression complete.
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.0112158 to fit
# [INFO] Huffman tree saved as /Users/bhalchandra/SEM1_NEU/huffman_tool/output/large_book_tree.png

# %%
# !python ../code/huffman_tool.py large_book.txt.huff decompress word
# Out:
# [INFO] Decompressing /Users/bhalchandra/SEM1_NEU/huffman_tool/output/large_book.txt.huff
#        Mode: word, Chunks: 4
# [INFO] Decompression complete. Output: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/uncompressed_large_book.txt.txt

# %% [markdown]
# ### Another smaller book

# %%
# !python ../code/huffman_tool.py 'Hints on news reporting by Murray Sheehan.txt' compress word
# Out:
# [INFO] Building global frequency table for: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/Hints on news reporting by Murray Sheehan.txt
# [INFO] Building global Huffman tree...
# [INFO] Writing code report: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/Hints on news reporting by Murray Sheehan_codes.txt
# [INFO] Code report saved to: /Users/bhalchandra/SEM1_NEU/huffman_tool/data/Hints on news reporting by Murray Sheehan_codes.txt
# [INFO] Writing global metadata: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/Hints on news reporting by Murray Sheehan.txt.huff.global.json
# [INFO] Starting second pass: encoding with global codes...
# [INFO] Writing chunk metadata: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/Hints on news reporting by Murray Sheehan.txt.huff.chunks.json
# [INFO] Actual compression ratio (file sizes): 72.02%
#        Original size:   86144 bytes
#        Compressed size: 24101 bytes
# [INFO] Streaming hybrid compression complete.
# dot: graph is too large for cairo-renderer bitmaps. Scaling by 0.122071 to fit
# [INFO] Huffman tree saved as /Users/bhalchandra/SEM1_NEU/huffman_tool/output/Hints on news reporting by Murray Sheehan_tree.png

# %%
# !python ../code/huffman_tool.py 'Hints on news reporting by Murray Sheehan.txt.huff' decompress word
# Out:
# [INFO] Decompressing /Users/bhalchandra/SEM1_NEU/huffman_tool/output/Hints on news reporting by Murray Sheehan.txt.huff
#        Mode: word, Chunks: 1
# [INFO] Decompression complete. Output: /Users/bhalchandra/SEM1_NEU/huffman_tool/output/uncompressed_Hints on news reporting by Murray Sheehan.txt.txt
